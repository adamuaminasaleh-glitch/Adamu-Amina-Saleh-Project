# %% [markdown]
# # Introduction
# In this notebook, we will explore some of the essential tools, languages, and libraries used in **Data Science**. We will also perform basic arithmetic operations using Python code examples

# %% [markdown]
# ## Data Science Languages
# Below are the list of Data Science Languages:
#  1. Python
#  2. SQL
#  3. R
#  4. Scala
#  5. Julia

# %% [markdown]
# ## Data Science Libraries
# Data science relies on a rich ecosystem of libraries, primarily in Python, to facilitate tasks from data manipulation and analysis to machine learning and visualization .Below are the list of some Data Science Libraries:
#  1. Pandas
#  2. Numpy
#  3. Matplotlib
#  4. TensorFlow
#  5. Scikit-Learn

# %% [markdown]
# ## Table of Data Science Tools
# | Data Science Tool| Description|
# | ------------------| --------------|
# | Jupyter Notebook| Interactive Computing Environment|
# | R Studio| IDE for R Programming|
# | Apache Spark| Big Data Processing Engine|
# | TensorFlow| Deep Learning Framework|
# | VS Code| Code Editor Supporting Multiple Languages|

# %% [markdown]
# ## Arithmetic Expression Examples
# In this section, we demonstrate basic arithmetic expressions in Python such as addition and multiplication

# %%
A = 3
B = 4
C = 5
print (A * B + C)
# Out:
# 17

# %% [markdown]
# ## Example 2 - Converting Minutes to Hour

# %%
minute = 200
hour = minute/60
print (minute/hour)
# Out:
# 60.0

# %% [markdown]
# ## Objectives
# Lessons learnt so far include the following:
# - Introduce data science tools and languages
# - Demonstrate markdown syntax usage
# - Perform simple arithmetic operation
# - Prepare a Jupyter notebook for submission

# %% [markdown]
# ## Author
# Adamu Amina Saleh
